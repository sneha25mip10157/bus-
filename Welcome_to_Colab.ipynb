# %% [markdown]
# <a href="https://colab.research.google.com/github/sneha25mip10157/bus-/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l1= [1,3,2,32,45,23,13,14,15]
l1.pop(3)
print(l1)
# Out:
# [1, 3, 2, 45, 23, 13, 14, 15]

# %%
fruits = []
f1 = input("enter a fruit:", )
fruits.append(f1)
f2 = input("enter a fruit:", )
fruits.append(f2)
f3 = input("enter a fruit:", )
fruits.append(f3)
f4 = input("enter a fruit:", )
fruits.append(f4)
f5 = input("enter a fruit:", )
fruits.append(f5)
f6 = input("enter a fruit:", )
fruits.append(f6)
f7 = input("enter a fruit:", )
fruits.append(f7)
print(fruits)
# Out:
# enter a fruit:mango
# enter a fruit:apple
# enter a fruit:banana
# enter a fruit:papaya
# enter a fruit:orange
# enter a fruit:grapes
# enter a fruit:strawberry
# ['mango', 'apple', 'banana', 'papaya', 'orange', 'grapes', 'strawberry']

# %%
marks = []
m1= int(input("enter marks:"))
marks.append(m1)
m2= int(input("enter marks:"))
marks.append(m2)
m3= int(input("enter marks:"))
marks.append(m3)
m4= int(input("enter marks:"))
marks.append(m4)
m5= int(input("enter marks:"))
marks.append(m5)
m6= int(input("enter marks:"))
marks.append(m6)
marks.sort()
print(marks)
# Out:
# enter marks:34
# enter marks:15
# enter marks:76
# enter marks:36
# enter marks:56
# enter marks:45
# [15, 34, 36, 45, 56, 76]
