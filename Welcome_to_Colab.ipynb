# %% [markdown]
# <a href="https://colab.research.google.com/github/sneha25mip10157/bus-/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dictionary = {
    "madad" : "help",
    "aasman" : "sky",
    "samundar" : "sea",
    "jwalamukhi" : "volcano"
}
word = input("The word you want meaning of:")
print(dictionary[word])
# Out:
# The word you want meaning of:madad
# help

# %%
s = set()
n = int(input("the numbers you want:"))
s.add(n)
n = int(input("the numbers you want:"))
s.add(n)
n = int(input("the numbers you want:"))
s.add(n)
n = int(input("the numbers you want:"))
s.add(n)
n = int(input("the numbers you want:"))
s.add(n)
n = int(input("the numbers you want:"))
s.add(n)
n = int(input("the numbers you want:"))
s.add(n)
n = int(input("the numbers you want:"))
s.add(n)
print(s)
# Out:
# the numbers you want:1
# the numbers you want:2
# the numbers you want:3
# the numbers you want:4
# the numbers you want:5
# the numbers you want:5
# the numbers you want:6
# the numbers you want:7
# {1, 2, 3, 4, 5, 6, 7}

# %%
s = {18,"18"}
print(s, type(s))
# Out:
# {18, '18'} <class 'set'>

# %%
s = set()
s.add(20)
s.add(20.0)
s.add('20')

l = len(s)
print(l)
# Out:
# 2

# %%
s = {}
print(type(s))
# Out:
# <class 'dict'>

# %%
d = {}
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
print(d)
# Out:
# Enter your name:Sneha
# Enter your favorite language:Hindi
# Enter your name:Sakshi
# Enter your favorite language:Sanskrit
# Enter your name:Yashu
# Enter your favorite language:Gujrati
# Enter your name:Pari
# Enter your favorite language:Rajasthani
# {'Sneha': 'Hindi', 'Sakshi': 'Sanskrit', 'Yashu': 'Gujrati', 'Pari': 'Rajasthani'}

# %%
d = {}
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
print(d)
# Out:
# Enter your name:Sneha
# Enter your favorite language:Hindi
# Enter your name:Sneha
# Enter your favorite language:Gujrati
# Enter your name:Sakshi
# Enter your favorite language:english
# Enter your name:yashu
# Enter your favorite language:tamil
# {'Sneha': 'Gujrati', 'Sakshi': 'english', 'yashu': 'tamil'}

# %%
d = {}
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
names = input("Enter your name:" )
language = input("Enter your favorite language:" )
d.update({names:language})
print(d)
# Out:
# Enter your name:me
# Enter your favorite language:hindi
# Enter your name:sakshi
# Enter your favorite language:hindi
# Enter your name:yashu
# Enter your favorite language:sanskrit
# Enter your name:pari
# Enter your favorite language:rajasthani
# {'me': 'hindi', 'sakshi': 'hindi', 'yashu': 'sanskrit', 'pari': 'rajasthani'}

# %%
s = {8,7,12,"Sneha"}
print(s)
# Out:
# {8, 12, 'Sneha', 7}
